# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Data Loading

# %% [markdown]
# ## 2. Data Exploratio

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ## 4. Data Encoding

# %% [markdown]
# ## 5. Data Normalization
